# %%
from scipy import stats
import numpy as np
import seaborn as sns

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
np.random.normal(loc=0,scale=1,size=10000)
# Out:
# array([ 0.48295613, -0.28316542, -0.69982668, ..., -0.61610029,
#        -0.44667346,  0.21216733])

# %%
data.shape
# Out:
# (10000,)

# %%
sns.distplot(np.random.normal(loc=0,scale=0.5,size=10000));
sns.distplot(np.random.normal(loc=0,scale=1,size=10000));
sns.distplot(np.random.normal(loc=0,scale=2,size=10000));
sns.distplot(np.random.normal(loc=0,scale=4,size=10000));

# %%
1/np.sqrt(2*np.pi)
# Out:
# 0.3989422804014327

# %%
sns.distplot(np.random.normal(loc=0,scale=1,size=10000));

# %%
# Given a z score, get area to left and right
stats.norm.cdf(-1), stats.norm.sf(-1)
# Out:
# (0.15865525393145707, 0.8413447460685429)

# %%
# Given area to left and right get z scores
stats.norm.ppf(0.5), stats.norm.isf(0.5)
# Out:
# (0.0, 0.0)

# %%
# where does this curve start?
stats.norm.ppf(0), stats.norm.isf(0)
# Out:
# (-inf, inf)

# %%
stats.norm.pdf(-1), stats.norm.pdf(1)
# Out:
# (0.24197072451914337, 0.24197072451914337)

# %%
x = -2
sigma = 1
mu = 0
z = (x - mu)/sigma

# %%
(1/np.sqrt(2*np.pi)) * np.exp(-0.5*(z**2))
# Out:
# 0.05399096651318806

# %%
stats.norm.cdf(-2.45)
# Out:
# 0.007142810735271415

# %%
sns.distplot(np.random.normal(loc=0,scale=1,size=10000))
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
mu = 2
sigma = 9
data = np.random.normal(loc=mu,scale=sigma,size=10000)

# %%
len(data[(data > mu) & (data < mu -0.67448*sigma)]), len(data[(data < mu) & (data > mu-10*sigma)])
# Out:
# (5097, 4903)

# %%
stats.norm.cdf(1) - stats.norm.cdf(0)
# Out:
# 0.3413447460685429

# %%
stats.norm.sf(0) - stats.norm.sf(1)
# Out:
# 0.3413447460685429

# %%
stats.norm.ppf(0.25), stats.norm.isf(0.25)
# Out:
# (-0.6744897501960817, 0.6744897501960817)

# %%
stats.norm.cdf(-2) + stats.norm.cdf(2)
# Out:
# 1.0

# %%
# want area to the right of z = -1
1 - stats.norm.cdf(-1)
# Out:
# 0.8413447460685429

# %%
stats.norm.ppf(0.1)
# Out:
# -1.2815515655446004

# %%
# area to left is 
left_area = 0.05
stats.norm.ppf(left_area)
# Out:
# -1.6448536269514729

# %%
# area to left is 
left_area = 0.025
stats.norm.ppf(left_area)
# Out:
# -1.9599639845400545

# %%
# first quartile is number below which is 25%, above which is 75%
stats.norm.ppf(0.25)
# Out:
# -0.6744897501960817

# %%
len(data[data < mu -0.67448*sigma])
# Out:
# 2471

# %%
mu = 2
sigma = 9
data = np.random.normal(loc=mu,scale=sigma,size=10000)
len(data[(data > mu) & (data < mu + sigma)]), len(data[(data < mu) & (data > mu-sigma)])
# Out:
# (3421, 3387)

# %%
mu = 8
sigma = 2
data2 = np.random.normal(loc=mu,scale=sigma,size=10000)

# %%
mu = 5
sigma = 12
data = np.random.normal(loc=mu,scale=sigma,size=10000)
len(data[(data > mu) & (data < mu + sigma)]), len(data[(data < mu) & (data > mu-sigma)])
# Out:
# (3536, 3264)

# %%
mu = 0
sigma = 1
data = np.random.normal(loc=mu,scale=sigma,size=10000)
len(data[(data > mu) & (data < mu + sigma)]), len(data[(data < mu) & (data > mu-sigma)])
# Out:
# (3406, 3448)
