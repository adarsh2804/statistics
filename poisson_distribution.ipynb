# %%
import numpy as np
from scipy import stats
import math

# %%
# stats.poisson.pmf(x,lambda)

stats.poisson.pmf(4,11)
# Out:
# 0.010188733386249454

# %%
np.exp(-11)*(11**4)/math.factorial(4)
# Out:
# 0.010188733386249446

# %% [markdown]
# ![image.png](attachment:image.png)
